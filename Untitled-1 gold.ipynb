# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

from statsmodels.tsa.arima_model import ARIMA

from statsmodels.tsa.arima.model import ARIMA

from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm

from statsmodels.tsa.holtwinters import ExponentialSmoothing

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\ExcelR\Project GOLD\Gold_data.csv")
df.head()
# Out:
#          date    price
# 0  2016-01-01  2252.60
# 1  2016-01-02  2454.50
# 2  2016-01-03  2708.10
# 3  2016-01-04  2577.80
# 4  2016-01-05  2597.75

# %%
# convert date column into datetime format
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#            date    price
# 0    2016-01-01  2252.60
# 1    2016-01-02  2454.50
# 2    2016-01-03  2708.10
# 3    2016-01-04  2577.80
# 4    2016-01-05  2597.75
# ...         ...      ...
# 2177 2021-12-17  4394.40
# 2178 2021-12-18  4389.50
# 2179 2021-12-19  4389.50
# 2180 2021-12-20  4354.10
# 2181 2021-12-21  4346.50
#
# [2182 rows x 2 columns]

# %%
# set date column as index
df.set_index('date',inplace=True)

# %%
df_price = pd.DataFrame(df['price'],columns=['price'])
df_price
# Out:
#               price
# date
# 2016-01-01  2252.60
# 2016-01-02  2454.50
# 2016-01-03  2708.10
# 2016-01-04  2577.80
# 2016-01-05  2597.75
# ...             ...
# 2021-12-17  4394.40
# 2021-12-18  4389.50
# 2021-12-19  4389.50
# 2021-12-20  4354.10
# 2021-12-21  4346.50
#
# [2182 rows x 1 columns]

# %% [markdown]
# # ARIMA MODEL

# %%
#!pip install pmdarima
from pmdarima import auto_arima

# %%
stepwise_fit = auto_arima(df_price.price, trace = True, suppress_warnings=True, seasonal=False)
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=26623.835, Time=1.93 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=26849.714, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=26851.587, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=26851.536, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=26847.869, Time=0.03 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=26631.605, Time=1.42 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=26635.529, Time=1.53 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=26625.835, Time=2.13 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=26625.835, Time=2.57 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=26662.140, Time=0.94 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=26629.134, Time=2.02 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=26633.886, Time=1.67 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=26613.890, Time=2.75 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=26592.600, Time=3.55 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=26599.038, Time=3.21 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=26591.818, Time=4.49 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=26616.474, Time=4.12 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : AIC=26602.345, Time=4.15 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=26565.720, Time=4.23 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=26597.637, Time=3.91 sec
#  ARIMA(4,1,5)(0,0,0)[0] intercept   : AIC=26592.627, Time=6.47 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=26594.947, Time=4.32 sec
#  ARIMA(5,1,5)(0,0,0)[0] intercept   : AIC=26556.679, Time=5.52 sec
#  ARIMA(5,1,5)(0,0,0)[0]             : AIC=inf, Time=4.18 sec
#
# Best model:  ARIMA(5,1,5)(0,0,0)[0] intercept
# Total fit time: 65.476 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2182
# Model:               SARIMAX(5, 1, 5)   Log Likelihood              -13266.339
# Date:                Wed, 07 Dec 2022   AIC                          26556.679
# Time:                        15:45:14   BIC                          26624.929
# Sample:                    01-01-2016   HQIC                         26581.629
#                          - 12-21-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.3705      0.545      0.680      0.496      -0.697       1.438
# ar.L1         -0.5005      0.018    -27.197      0.000      -0.537      -0.464
# ar.L2         -0.5349      0.022    -24.838      0.000      -0.577      -0.493
# ar.L3         -0.0385      0.027     -1.429      0.153      -0.091       0.014
# ar.L4          0.0536      0.021      2.574      0.010       0.013       0.094
# ar.L5          0.7772      0.016     47.657      0.000       0.745       0.809
# ma.L1          0.3546      0.013     26.827      0.000       0.329       0.380
# ma.L2          0.2776      0.014     19.907      0.000       0.250       0.305
# ma.L3         -0.2315      0.015    -15.939      0.000      -0.260      -0.203
# ma.L4         -0.3018      0.012    -24.147      0.000      -0.326      -0.277
# ma.L5         -0.9298      0.011    -85.011      0.000      -0.951      -0.908
# sigma2       1.19e+04    179.168     66.397      0.000    1.15e+04    1.22e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   9.58   Jarque-Bera (JB):             35962.03
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.46   Skew:                            -1.36
# Prob(H) (two-sided):                  0.00   Kurtosis:                        22.71
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
final_arima_model = sm.tsa.ARIMA(df_price['price'],order = (5,1,5))
arima_fit_final = final_arima_model.fit()

# %%
# forecast for next 30 days

forecast = arima_fit_final.predict(len(df_price), len(df_price)+29)
forecast_df = pd.DataFrame(forecast)
forecast_df.columns = ['price']
forecast_df
# Out:
#                   price
# 2021-12-22  4378.430245
# 2021-12-23  4364.515752
# 2021-12-24  4369.433985
# 2021-12-25  4355.790924
# 2021-12-26  4308.053417
# 2021-12-27  4364.248296
# 2021-12-28  4350.091677
# 2021-12-29  4332.901314
# 2021-12-30  4334.435776
# 2021-12-31  4308.692000
# 2022-01-01  4365.069849
# 2022-01-02  4337.399832
# 2022-01-03  4309.782541
# 2022-01-04  4336.667215
# 2022-01-05  4320.817348
# 2022-01-06  4358.568279
# 2022-01-07  4323.426136
# 2022-01-08  4302.189974
# 2022-01-09  4350.567000
# 2022-01-10  4327.266176
# 2022-01-11  4342.482909
# 2022-01-12  4316.680511
# 2022-01-13  4308.687042
# 2022-01-14  4362.468840
# 2022-01-15  4322.178272
# 2022-01-16  4325.792455
# 2022-01-17  4322.669955
# 2022-01-18  4320.163795
# 2022-01-19  4362.990183
# 2022-01-20  4310.905072

# %%
# Set appropriate date as index for plotting forecast data

datetime = pd.date_range('2021-12-22', periods=30,freq='B')
date_df = pd.DataFrame(datetime,columns=['date'])

data_forecast = forecast_df.set_index(date_df.date)
data_forecast
# Out:
#                   price
# date
# 2021-12-22  4378.430245
# 2021-12-23  4364.515752
# 2021-12-24  4369.433985
# 2021-12-27  4355.790924
# 2021-12-28  4308.053417
# 2021-12-29  4364.248296
# 2021-12-30  4350.091677
# 2021-12-31  4332.901314
# 2022-01-03  4334.435776
# 2022-01-04  4308.692000
# 2022-01-05  4365.069849
# 2022-01-06  4337.399832
# 2022-01-07  4309.782541
# 2022-01-10  4336.667215
# 2022-01-11  4320.817348
# 2022-01-12  4358.568279
# 2022-01-13  4323.426136
# 2022-01-14  4302.189974
# 2022-01-17  4350.567000
# 2022-01-18  4327.266176
# 2022-01-19  4342.482909
# 2022-01-20  4316.680511
# 2022-01-21  4308.687042
# 2022-01-24  4362.468840
# 2022-01-25  4322.178272
# 2022-01-26  4325.792455
# 2022-01-27  4322.669955
# 2022-01-28  4320.163795
# 2022-01-31  4362.990183
# 2022-02-01  4310.905072

# %%
plt.figure(figsize=(15,6), dpi=100)
plt.plot(df_price, label = 'Actual')
plt.plot(data_forecast, label='Forecast',color='red')
plt.title('Actual vs Forecast')
plt.legend(loc='upper left', fontsize=10)
plt.grid(True)
plt.show()

# %% [markdown]
# # Demployment

# %%
# !pip install dump
from pickle import dump
# Out:
# Requirement already satisfied: dump in c:\users\shantanu khamkar\anaconda3\lib\site-packages (0.0.5)

# %%
dump(arima_fit_final,open('arima_fit_final.sav','wb'))

# %%
dump(df_price,open('df_price.sav','wb'))
dump(datetime,open('datetime.sav','wb'))
